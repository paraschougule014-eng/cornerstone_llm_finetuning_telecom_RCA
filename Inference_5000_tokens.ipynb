# %%
pip install "torch>=2.0.0" "transformers>=4.51.0" accelerate pandas tqdm huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 110.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.5/645.5 kB 79.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 201.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 202.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.1/801.1 kB 129.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [transformers] [transformers]ub]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python run_inference.py \
    --test_csv phase_1_test.csv \
    --truth_csv phase_1_test_truth.csv \
    --output predictions.csv \
    --batch_size 32
# Out:
# /teamspace/studios/this_studio/run_inference.py:11: SyntaxWarning: invalid escape sequence '\ '
#   --truth_csv phase_1_test_truth.csv \   # optional, for accuracy eval
# [INFO] GPU: NVIDIA H100 80GB HBM3
# [INFO] VRAM: 85.0 GB
#
# [INFO] Loading model: Paras014/qwen35_2b_finetune_16bit_final
# ...
# `torch_dtype` is deprecated! Use `dtype` instead!
# The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights: 100%|███████████████████████| 617/617 [00:02<00:00, 264.48it/s]
# [INFO] torch.compile() applied.
# [INFO] Model loaded.
#
# [INFO] Loaded 864 samples from phase_1_test.csv
# [INFO] Batch size: 32
# [INFO] Total batches: 27
#
#   Batch 1/27 | 32/864 samples | 0.2 samples/s | ETA 4789s
#   Batch 2/27 | 64/864 samples | 0.2 samples/s | ETA 4620s
# ...
